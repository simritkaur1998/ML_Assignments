# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
x=df['Evaporation']
x.head()
# Out:
# 0    3.4
# 1    4.4
# 2    5.8
# 3    7.2
# 4    5.6
# Name: Evaporation, dtype: float64

# %%
sns.distplot(x)

# %%
sns.distplot(x, kde=False, rug=False)

# %%
sns.distplot(x, kde=False, rug=True)

# %%
sns.distplot(x, hist=False, rug=False)

# %%
sns.distplot(x, hist=False, rug=True)

# %%
sns.kdeplot(x, shade=True)

# %%
x=df['MaxTemp']
sns.kdeplot(x, label='original')
sns.kdeplot(x, bw=0.5, label='bw=0.5')
sns.kdeplot(x, bw=5, label='bw=5')
plt.legend()

# %%
x = pd.DataFrame(df, columns=['WindGustSpeed', 'WindSpeed9am'])

# %%
x.head(1)
# Out:
#    WindGustSpeed  WindSpeed9am
# 0           30.0           6.0

# %%
x.plot(kind='scatter' , x='WindGustSpeed' , y='WindSpeed9am')

# %%
sns.jointplot(x='WindGustSpeed' , y='WindSpeed9am', data=x)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
a=pd.DataFrame(df, columns=['MinTemp', 'MaxTemp'])
with sns.axes_style('white'):
    sns.jointplot(x = df['MinTemp'], y =df['MaxTemp'], kind = 'hex', color = 'k', data=a )

# %%
sns.jointplot(x=df['MinTemp'], y=df['MaxTemp'],  kind='kde')

# %%
a=pd.DataFrame(df, columns=['Humidity9am','Humidity3pm','Pressure9am','Pressure3pm'])
sns.pairplot(a)

# %%
a=pd.DataFrame(df)

# %%
a.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.stripplot(x ='WindGustDir', y='WindGustSpeed', data=a,jitter=False)

# %%
sns.stripplot(x ='WindGustDir', y='WindGustSpeed', data=a,jitter=True)

# %%
sns.swarmplot(x ='WindGustDir', y='WindGustSpeed', data=a)

# %%
sns.boxplot(x ='WindGustDir', y='WindGustSpeed', data=a)

# %%
sns.boxplot(x='RainToday', y='Humidity3pm', data=a, hue='WindDir3pm', dodge=True)

# %%
sns.barplot(x ='WindGustDir', y='WindGustSpeed', data=a)

# %%
sns.barplot(x ='WindGustDir', y='WindGustSpeed', data=a, hue='RainToday')

# %%
sns.countplot(x='WindGustDir', data=a, palette='Greens_d')
